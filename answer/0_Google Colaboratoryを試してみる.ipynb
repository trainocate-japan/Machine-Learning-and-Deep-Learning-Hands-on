# %% [markdown]
# <a target="_blank" href="https://colab.research.google.com/github/trainocate-japan/Machine-Learning-and-Deep-Learning-Hands-on/blob/main/answer/0_Google Colaboratoryを試してみる.ipynb">
#   <img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/>
# </a>

# %% [markdown]
# # Google Colaboratoryを試してみる
#
# 下のセルの左側にある [　] の部分にマウスカーソルを合わせると、実行を表す ▶ に表示が変わります。
# クリックしてプログラムを実行してみましょう。

# %%
# こちらはPythonのプログラムです。
# 実行すると10 + 20 の答え 30 が表示されます
a = 10
b = 20
c = a + b

c

# %% [markdown]
# 確認は以上です。
#
# Google Colaboratoryは自動で保存がされます。
# 終了するときは、そのままブラウザのタブを閉じて終了します。
